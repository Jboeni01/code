# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestRegressor
import os

os.chdir('C:\\Users\justu\\Desktop\\Masterarbeit\\Data\\CE')
os.getcwd()
# Out:
# 'C:\\Users\\justu\\Desktop\\Masterarbeit\\Data\\CE'

# %%
#check = pd.read_csv('fs08.csv')
print('the number of variables is:')
print(len(list(check)))
print('number of observation per given variable:')
print(check.count())
column_types = list(check.dtypes)

#print(list(check.percentile()))
column_names = list(check)

#check.select_dtypes(exlude=['float'])
#check.select_dtypes(exclude=['object'])

column_types
#arraycheck = np.array(check)
#for i in range(len(arraycheck[0,:])):
#    print(np.mean(arraycheck[:,i]))
##['CUTENURE' + f'_{j}' for j in list(range(1,6)) if j!=3]
# Out:
# the number of variables is:
# 121
# number of observation per given variable:
# CustID            25989
# QINTRVYR          25989
# QINTRVMO          25989
# NEWID             25989
# AGE_REF           25989
# AGE2              14503
# CKBKACTX           3234
# CKBK_CTX          25989
# CUTENURE          25989
# FAM_SIZE          25989
# FINCBTAX          25989
# MARITAL1          25989
# PERSLT18          25989
# RESPSTAT          25989
# SAVACCTX           3240
# SAVA_CTX          25989
# SECESTX             601
# SECESTX_          25989
# ST_HOUS           25989
# FDHOMEPQ          25989
# FDHOMECQ          25989
# FDAWAYPQ          25989
# FDAWAYCQ          25989
# ALCBEVPQ          25989
# ALCBEVCQ          25989
# SHELTPQ           25989
# SHELTCQ           25989
# UTILPQ            25989
# UTILCQ            25989
# HOUSOPPQ          25989
#                   ...
# rbtmo_2            4889
# diff_2             4889
# rbtamt             4339
# rbtamt_chk         2545
# rbtamt_e           1764
# intrvyr_max       25989
# intrvmo_max       25989
# age               25989
# adults            25989
# timetrend         25989
# int_entries       25989
# last_timetrend    17769
# chg_timetrend     17769
# last_FD           17769
# chg_FD            17769
# last_SND          17769
# chg_SND           17769
# last_ND           17769
# chg_ND            17769
# last_DUR          17769
# chg_DUR           17769
# totalint          25989
# timeleft          11941
# time              11942
# newmrrt_median    11941
# nmorg             11942
# qescrowx_sum      11942
# qblncm1x_sum      11942
# orgmrtx_sum       11942
# morgpayment       11941
# Length: 121, dtype: int64
# int64
# [(dtype('int64'), 'CustID'), (dtype('int64'), 'QINTRVYR'), (dtype('int64'), 'QINTRVMO'), (dtype('int64'), 'NEWID'), (dtype('int64'), 'AGE_REF'), (dtype('float64'), 'AGE2'), (dtype('float64'), 'CKBKACTX'), (dtype('O'), 'CKBK_CTX'), (dtype('int64'), 'CUTENURE'), (dtype('int64'), 'FAM_SIZE'), (dtype('int64'), 'FINCBTAX'), (dtype('int64'), 'MARITAL1'), (dtype('int64'), 'PERSLT18'), (dtype('int64'), 'RESPSTAT'), (dtype('float64'), 'SAVACCTX'), (dtype('O'), 'SAVA_CTX'), (dtype('float64'), 'SECESTX'), (dtype('O'), 'SECESTX_'), (dtype('int64'), 'ST_HOUS'), (dtype('float64'), 'FDHOMEPQ'), (dtype('float64'), 'FDHOMECQ'), (dtype('float64'), 'FDAWAYPQ'), (dtype('float64'), 'FDAWAYCQ'), (dtype('float64'), 'ALCBEVPQ'), (dtype('float64'), 'ALCBEVCQ'), (dtype('float64'), 'SHELTPQ'), (dtype('float64'), 'SHELTCQ'), (dtype('float64'), 'UTILPQ'), (dtype('float64'), 'UTILCQ'), (dtype('float64'), 'HOUSOPPQ'), (dtype('float64'), 'HOUSOPCQ'), (dtype('float64'), 'HOUSEQPQ'), (dtype('float64'), 'HOUSEQCQ'), (dtype('float64'), 'APPARPQ'), (dtype('float64'), 'APPARCQ'), (dtype('int64'), 'CARTKNPQ'), (dtype('int64'), 'CARTKNCQ'), (dtype('int64'), 'OTHVEHPQ'), (dtype('int64'), 'OTHVEHCQ'), (dtype('float64'), 'GASMOPQ'), (dtype('float64'), 'GASMOCQ'), (dtype('int64'), 'VEHFINPQ'), (dtype('int64'), 'VEHFINCQ'), (dtype('float64'), 'MAINRPPQ'), (dtype('float64'), 'MAINRPCQ'), (dtype('int64'), 'VEHINSPQ'), (dtype('int64'), 'VEHINSCQ'), (dtype('float64'), 'VRNTLOPQ'), (dtype('float64'), 'VRNTLOCQ'), (dtype('float64'), 'PUBTRAPQ'), (dtype('float64'), 'PUBTRACQ'), (dtype('float64'), 'HEALTHPQ'), (dtype('float64'), 'HEALTHCQ'), (dtype('float64'), 'ENTERTPQ'), (dtype('float64'), 'ENTERTCQ'), (dtype('float64'), 'PERSCAPQ'), (dtype('float64'), 'PERSCACQ'), (dtype('float64'), 'READPQ'), (dtype('float64'), 'READCQ'), (dtype('int64'), 'EDUCAPQ'), (dtype('int64'), 'EDUCACQ'), (dtype('float64'), 'TOBACCPQ'), (dtype('float64'), 'TOBACCCQ'), (dtype('float64'), 'MISCPQ'), (dtype('float64'), 'MISCCQ'), (dtype('float64'), 'FINCBTXM'), (dtype('float64'), 'FSALARYM'), (dtype('int64'), 'Year'), (dtype('O'), 'Quarter'), (dtype('float64'), 'FD'), (dtype('float64'), 'SND'), (dtype('float64'), 'ND'), (dtype('float64'), 'DUR'), (dtype('int64'), 'valid_finassets'), (dtype('float64'), 'finassets'), (dtype('float64'), 'rbtnr_perint'), (dtype('float64'), 'CUID'), (dtype('float64'), 'last_rbtamt'), (dtype('float64'), 'last_rbtamt_chk'), (dtype('float64'), 'last_rbtamt_e'), (dtype('float64'), 'fut_rbtamt'), (dtype('float64'), 'fut_rbtamt_chk'), (dtype('float64'), 'fut_rbtamt_e'), (dtype('float64'), 'rbtamt_1'), (dtype('float64'), 'rbtamt_chk_1'), (dtype('float64'), 'rbtamt_e_1'), (dtype('float64'), 'rbtmo_1'), (dtype('float64'), 'diff_1'), (dtype('float64'), 'rbtamt_2'), (dtype('float64'), 'rbtamt_chk_2'), (dtype('float64'), 'rbtamt_e_2'), (dtype('float64'), 'rbtmo_2'), (dtype('float64'), 'diff_2'), (dtype('float64'), 'rbtamt'), (dtype('float64'), 'rbtamt_chk'), (dtype('float64'), 'rbtamt_e'), (dtype('int64'), 'intrvyr_max'), (dtype('int64'), 'intrvmo_max'), (dtype('float64'), 'age'), (dtype('int64'), 'adults'), (dtype('int64'), 'timetrend'), (dtype('int64'), 'int_entries'), (dtype('float64'), 'last_timetrend'), (dtype('float64'), 'chg_timetrend'), (dtype('float64'), 'last_FD'), (dtype('float64'), 'chg_FD'), (dtype('float64'), 'last_SND'), (dtype('float64'), 'chg_SND'), (dtype('float64'), 'last_ND'), (dtype('float64'), 'chg_ND'), (dtype('float64'), 'last_DUR'), (dtype('float64'), 'chg_DUR'), (dtype('int64'), 'totalint'), (dtype('float64'), 'timeleft'), (dtype('float64'), 'time'), (dtype('float64'), 'newmrrt_median'), (dtype('float64'), 'nmorg'), (dtype('float64'), 'qescrowx_sum'), (dtype('float64'), 'qblncm1x_sum'), (dtype('float64'), 'orgmrtx_sum'), (dtype('float64'), 'morgpayment')]
# variables where the number of observations is larger than 20000
# ['CustID', 'QINTRVYR', 'QINTRVMO', 'NEWID', 'AGE_REF', 'CKBK_CTX', 'CUTENURE', 'FAM_SIZE', 'FINCBTAX', 'MARITAL1', 'PERSLT18', 'RESPSTAT', 'SAVA_CTX', 'SECESTX_', 'ST_HOUS', 'FDHOMEPQ', 'FDHOMECQ', 'FDAWAYPQ', 'FDAWAYCQ', 'ALCBEVPQ', 'ALCBEVCQ', 'SHELTPQ', 'SHELTCQ', 'UTILPQ', 'UTILCQ', 'HOUSOPPQ', 'HOUSOPCQ', 'HOUSEQPQ', 'HOUSEQCQ', 'APPARPQ', 'APPARCQ', 'CARTKNPQ', 'CARTKNCQ', 'OTHVEHPQ', 'OTHVEHCQ', 'GASMOPQ', 'GASMOCQ', 'VEHFINPQ', 'VEHFINCQ', 'MAINRPPQ', 'MAINRPCQ', 'VEHINSPQ', 'VEHINSCQ', 'VRNTLOPQ', 'VRNTLOCQ', 'PUBTRAPQ', 'PUBTRACQ', 'HEALTHPQ', 'HEALTHCQ', 'ENTERTPQ', 'ENTERTCQ', 'PERSCAPQ', 'PERSCACQ', 'READPQ', 'READCQ', 'EDUCAPQ', 'EDUCACQ', 'TOBACCPQ', 'TOBACCCQ', 'MISCPQ', 'MISCCQ', 'FINCBTXM', 'FSALARYM', 'Year', 'Quarter', 'FD', 'SND', 'ND', 'DUR', 'valid_finassets', 'intrvyr_max', 'intrvmo_max', 'age', 'adults', 'timetrend', 'int_entries', 'totalint']
# [dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('O'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('float64'),
#  dtype('O'),
#  dtype('float64'),
#  dtype('O'),
#  dtype('int64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('int64'),
#  dtype('O'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('int64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('float64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('int64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64')]

# %% [markdown]
# Select data types that are not objects

# %%
c_types_names = list(zip(column_types,column_names))
c_types_names_spec = [i for i in c_types_names if type(i[0])=='obj']

c_names_spec = [i[1] for i in c_types_names_spec]

# %% [markdown]
# Select data types where we have observations above a certain threshold

# %%
column_count = list(check.count())
c_count_names = list(zip(column_count,column_names))
c_count_names_spec = [i for i in c_count_names if i[0] > 20000]
print('variables where the number of observations is larger than 20000')
c_names_spec = [i[1] for i in c_count_names_spec]
print(c_names_spec)
checkdes = check.loc[:,c_names_spec].describe()
checkdes.index[:]
checkdes.loc['25%',:]
# Out:
# variables where the number of observations is larger than 20000
# ['CustID', 'QINTRVYR', 'QINTRVMO', 'NEWID', 'AGE_REF', 'CKBK_CTX', 'CUTENURE', 'FAM_SIZE', 'FINCBTAX', 'MARITAL1', 'PERSLT18', 'RESPSTAT', 'SAVA_CTX', 'SECESTX_', 'ST_HOUS', 'FDHOMEPQ', 'FDHOMECQ', 'FDAWAYPQ', 'FDAWAYCQ', 'ALCBEVPQ', 'ALCBEVCQ', 'SHELTPQ', 'SHELTCQ', 'UTILPQ', 'UTILCQ', 'HOUSOPPQ', 'HOUSOPCQ', 'HOUSEQPQ', 'HOUSEQCQ', 'APPARPQ', 'APPARCQ', 'CARTKNPQ', 'CARTKNCQ', 'OTHVEHPQ', 'OTHVEHCQ', 'GASMOPQ', 'GASMOCQ', 'VEHFINPQ', 'VEHFINCQ', 'MAINRPPQ', 'MAINRPCQ', 'VEHINSPQ', 'VEHINSCQ', 'VRNTLOPQ', 'VRNTLOCQ', 'PUBTRAPQ', 'PUBTRACQ', 'HEALTHPQ', 'HEALTHCQ', 'ENTERTPQ', 'ENTERTCQ', 'PERSCAPQ', 'PERSCACQ', 'READPQ', 'READCQ', 'EDUCAPQ', 'EDUCACQ', 'TOBACCPQ', 'TOBACCCQ', 'MISCPQ', 'MISCCQ', 'FINCBTXM', 'FSALARYM', 'Year', 'Quarter', 'FD', 'SND', 'ND', 'DUR', 'valid_finassets', 'intrvyr_max', 'intrvmo_max', 'age', 'adults', 'timetrend', 'int_entries', 'totalint']
# CustID             1.882640e+05
# QINTRVYR           2.008000e+03
# QINTRVMO           3.000000e+00
# NEWID              1.882644e+06
# AGE_REF            3.800000e+01
# CUTENURE           1.000000e+00
# FAM_SIZE           1.000000e+00
# FINCBTAX           1.424900e+04
# MARITAL1           1.000000e+00
# PERSLT18           0.000000e+00
# RESPSTAT           1.000000e+00
# ST_HOUS            2.000000e+00
# FDHOMEPQ           3.543333e+02
# FDHOMECQ           0.000000e+00
# FDAWAYPQ           6.500010e+01
# FDAWAYCQ           0.000000e+00
# ALCBEVPQ           0.000000e+00
# ALCBEVCQ           0.000000e+00
# SHELTPQ            5.000000e+02
# SHELTCQ            0.000000e+00
# UTILPQ             2.783333e+02
# UTILCQ             0.000000e+00
# HOUSOPPQ           0.000000e+00
# HOUSOPCQ           0.000000e+00
# HOUSEQPQ           0.000000e+00
# HOUSEQCQ           0.000000e+00
# APPARPQ            0.000000e+00
# APPARCQ            0.000000e+00
# CARTKNPQ           0.000000e+00
# CARTKNCQ           0.000000e+00
#                        ...
# PUBTRACQ           0.000000e+00
# HEALTHPQ           2.500000e+01
# HEALTHCQ           0.000000e+00
# ENTERTPQ           7.700000e+01
# ENTERTCQ           0.000000e+00
# PERSCAPQ           0.000000e+00
# PERSCACQ           0.000000e+00
# READPQ             0.000000e+00
# READCQ             0.000000e+00
# EDUCAPQ            0.000000e+00
# EDUCACQ            0.000000e+00
# TOBACCPQ           0.000000e+00
# TOBACCCQ           0.000000e+00
# MISCPQ             0.000000e+00
# MISCCQ             0.000000e+00
# FINCBTXM           2.590000e+04
# FSALARYM           8.000000e+03
# Year               2.008000e+03
# FD                 1.091000e+03
# SND                2.542000e+03
# ND                 3.109300e+03
# DUR                1.878000e+03
# valid_finassets    0.000000e+00
# intrvyr_max        2.008000e+03
# intrvmo_max        2.000000e+00
# age                3.800000e+01
# adults             1.000000e+00
# timetrend          4.000000e+00
# int_entries        1.000000e+00
# totalint           3.000000e+00
# Name: 25%, Length: 73, dtype: float64
